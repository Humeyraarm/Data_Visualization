# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

import warnings;
warnings.filterwarnings('ignore')

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]

salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]

salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %% [markdown]
# **Optional**

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)), fontsize=18, ha='center')
    plt.title(f"Subplot: {i}")

plt.suptitle("This is Functional Matplotlib Subplots Created By For Loop")
plt.tight_layout() 

plt.show()

# %% [markdown]
# # Adding Text Inside the Plot in Matplotlib
#
# The matplotlib.pyplot.text() function is used to add text inside the plot. The syntax adds text at an arbitrary location of the axes. It also supports mathematical expressions.
#
# **Syntax:** matplotlib.pyplot.text(x, y, s, fontdict=None, **kwargs)
#
# Parameters:
#
# - where x, y – coordinates
# - s – text to be added inside the plot(string)
# - fontdict – optional parameter. It overrides the default text properties
# - **kwargs – text properties
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.text.html
#
# https://www.geeksforgeeks.org/add-text-inside-the-plot-in-matplotlib/

# %% [markdown]
# # SPECIAL PLOT TYPES

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# A **`scatter plot`** (2D) is a useful method of comparing variables against each other.Shows relationship btw two quantitative variables.

# %%
x = np.array([15, 17, 18, 17, 12, 17, 12, 19, 14, 11, 12, 19, 16, 13])
y = np.array([99, 86, 87, 88, 81, 86, 93, 87, 94, 78, 77, 85, 86, 85])

plt.scatter(x, y)
plt.show()

# %%
y = np.random.randint(10, 100, 50)
x = np.random.randint(10, 100, 50)

plt.scatter(x,y);

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(12, 8))

plt.scatter(tips['tip'], tips['total_bill']);

# %% [markdown]
# # Bar Plot/Charts
#
# Often used with nominal and ordinal variables.Each bar represent different attributes of a variable.Heihgt of each bar reflects the frequencies for each attributes.

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23, 17, 35, 29, 12]

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.bar(langs, students);

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.barh(langs, students);

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
day_sum = tips.groupby(tips["day"]).sum()
day_sum                                    #sum only numerics  #alternate tips.groupby('day').sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
day = tips.groupby("day").sum().index   
day
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, dtype='category', name='day')

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
#day_sum=tips.groupby("day").sum()
#day = tips.groupby("day").sum().index 

total = day_sum["tip"].values

fig, ax = plt.subplots()
ax.barh(day,total);

# %%
total_tips = tips.groupby("day").sum()["tip"].values
total_bill = tips.groupby("day").sum()["total_bill"].values

fig, ax = plt.subplots()
ax.bar(day,total_bill, label = 'total bill')
ax.bar(day,total_tips, label = 'tip')
plt.legend();

# %%
p
# Out:
# array([0, 1, 2, 3])

# %%
# Optional hard to coding

fig, ax = plt.subplots(figsize=(10, 5))

p = np.arange(len(day))
width = 0.20

ax.bar(p - width/2, total_bill, width, label="total_bill")
ax.bar(p + width/2, total_tips, width, label="tip")

ax.set_xticks(p)
ax.set_xticklabels(day)

plt.legend()
plt.show()

# %% [markdown]
# # Histogram

# %%
np.random.seed(42)

x = np.random.randn(250)

plt.hist(x, bins = 30)
plt.show()

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
plt.hist(tips['total_bill'], bins= 50)
plt.show()

# %%
plt.hist(tips['tip'])
plt.show()

# %% [markdown]
# # Box Plot

# %% [markdown]
# A `box plot` is a way of statistically representing the *distribution* of the data through five main dimensions:
#
# *   **Minimum:** The smallest number in the dataset excluding the outliers.
# *   **First quartile:** Middle number between the `minimum` and the `median`.
# *   **Second quartile (Median):** Middle number of the (sorted) dataset.
# *   **Third quartile:** Middle number between `median` and `maximum`.
# *   **Maximum:** The largest number in the dataset excluding the outliers.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%203/images/boxplot_complete.png" width=440, align="center">

# %%
X = np.random.normal(170, 10, 250)
plt.boxplot(X)
plt.show()

# %%
plt.boxplot(X, vert = False)
plt.show()

# %%
box = np.array(np.random.rand(10, 4))
box
# Out:
# array([[0.19954245, 0.68022824, 0.07219841, 0.0306525 ],
#        [0.25768289, 0.46262296, 0.86827251, 0.72716907],
#        [0.74270652, 0.42549333, 0.34593499, 0.37103876],
#        [0.98764956, 0.04010919, 0.8670315 , 0.57867541],
#        [0.43861542, 0.72525766, 0.48666894, 0.87342324],
#        [0.90070186, 0.42172093, 0.2768278 , 0.59235033],
#        [0.91236335, 0.21066219, 0.62296658, 0.63156022],
#        [0.73311302, 0.13156769, 0.71582496, 0.90903252],
#        [0.17968311, 0.23754332, 0.97139509, 0.18097695],
#        [0.85438509, 0.49227786, 0.24723107, 0.8707499 ]])

# %%
plt.boxplot(box, labels=['A', 'B', 'C', 'D'])
plt.show()

# %%
plt.boxplot(tips['tip'])
plt.show()

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.iloc[:, 0:2]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
plt.boxplot((tips.iloc[:, 0:2]), labels=['total_bill', 'tip'])
plt.show()

# %% [markdown]
# # Pie Chart
#
# A `pie chart` is a circular graphic that displays numeric proportions by dividing a circle (or pie) into proportional slices. You are most likely already familiar with pie charts as it is widely used in business and media. We can create pie charts in Matplotlib by passing in the `kind=pie` keyword.

# %%
plt.figure(figsize=(10, 8))

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels=mylabels, labeldistance=0.7, autopct="%.2f")
plt.show()

# %% [markdown]
# The above visual is not very clear, the numbers and text overlap in some instances. Let's make a few modifications to improve the visuals:
#
# *   Remove the text labels on the pie chart by passing in `legend` and add it as a seperate legend using `plt.legend()`.
# *   Push out the percentages to sit just outside the pie chart by passing in `pctdistance` parameter.
# *   Pass in a custom set of colors for continents by passing in `colors` parameter.
# *   **Explode** the pie chart to emphasize the lowest three continents (Bananas, Apples, Dates and Cherries) by passing in `explode` parameter.

# %%
plt.figure(figsize=(10, 8))

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

myexplode = [0, 0.1, 0, 0]

plt.pie(y, labels = mylabels, explode=myexplode, labeldistance=None, autopct="%.1f")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))

colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.


y = np.array([25, 35, 25, 15])
mylabels = ["Bananas", "Apples", "Cherries", "Dates"]

plt.pie(y, 
        labels = mylabels,
        labeldistance=0.7, 
        autopct="%.1f", 
        startangle=90, 
        shadow=True, 
        pctdistance=1.1, 
        colors=colors_list, 
        explode=explode_list)

plt.legend()
plt.show()

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # PANDAS EASY PLOTS

# %%
tips.plot();   #default line plot

# %% [markdown]
# **Scatter w Pandas**

# %%
tips.plot.scatter(x='tip', y='total_bill');

# %%
tips.plot(x='tip', y='total_bill', kind ="scatter");

# %% [markdown]
# **Bar w Pandas**

# %%
df = pd.DataFrame(np.random.rand(5, 4), columns=['a', 'b', 'c', 'd'])
print(df)
df.plot.bar()
# df.plot.bar(rot=0)
# plt.legend(loc=(1.04, 0));
# Out:
#           a         b         c         d
# 0  0.160760  0.817967  0.832134  0.507468
# 1  0.006386  0.287038  0.616927  0.981186
# 2  0.631814  0.259804  0.634006  0.539985
# 3  0.779845  0.106981  0.761028  0.541267
# 4  0.962992  0.341872  0.632622  0.932028
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(5, 4), columns=['a', 'b', 'c', 'd'])
df.plot.bar(stacked=True);

# %%
tips.groupby("day")["tip"].sum()
# Out:
# day
# Thur    171.83
# Fri      51.96
# Sat     260.40
# Sun     247.39
# Name: tip, dtype: float64

# %%
tips.groupby("day")["tip"].sum().plot.bar(x="day", y="tip");

# %%
tips.groupby("sex")["tip"].sum().plot.bar(x="sex",y="tip");

# %% [markdown]
# **Histogram w Pandas**

# %%
tips.plot.hist(bins=50);

# %%
tips[["tip", "total_bill", "size"]].diff().hist(bins=10)
plt.show()

# %% [markdown]
# **Box plot w Pandas**

# %%
tips.plot.box();

# %% [markdown]
# **Pie chart w Pandas**

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby("day").sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
tips.groupby("day").sum().plot.pie(subplots=True, figsize=(18, 5), autopct="%.2f", labeldistance=0.8)
plt.legend()
plt.show()

# %% [markdown]
# # Kernel Density Estimation

# %%
df = pd.Series(np.random.randn(1000))

df.plot.kde();

# %%
tips.groupby("day")["size", "tip"].sum().plot.kde();

# %% [markdown]
# # DIMENSIONAL PLOTTING IN MATPLOTLIB
#
# <a id="14"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
#
# Matplotlib was introduced keeping in mind, only two-dimensional plotting. But at the time when the release of 1.0 occurred, the 3d utilities were developed upon the 2d and thus, we have 3d implementation of data available today! The 3d plots are enabled by importing the mplot3d toolkit.
#
# https://www.tutorialspoint.com/matplotlib/matplotlib_three_dimensional_plotting.htm
#
# https://towardsdatascience.com/an-easy-introduction-to-3d-plotting-with-matplotlib-801561999725
#
# https://www.geeksforgeeks.org/three-dimensional-plotting-in-python-using-matplotlib/
#
# https://jakevdp.github.io/PythonDataScienceHandbook/04.12-three-dimensional-plotting.html
#
# https://www.youtube.com/watch?v=gqoLLGgbeAE
#
# https://www.youtube.com/watch?v=6ljHxJQ47Uk

# %%
from mpl_toolkits import mplot3d

fig = plt.figure(figsize=(12, 8))
ax = plt.axes(projection='3d')

# %%
# Data for a three-dimensional line

zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(projection='3d')

ax.plot3D(xline, yline, zline, 'gray');

# %%
# Data for three-dimensional scattered points

zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(projection='3d')

ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Reds');
